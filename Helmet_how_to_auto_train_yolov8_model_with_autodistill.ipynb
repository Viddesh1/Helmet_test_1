# %% [markdown]
# <a href="https://colab.research.google.com/github/Viddesh1/Helmet_test_1/blob/main/Helmet_how_to_auto_train_yolov8_model_with_autodistill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://ik.imagekit.io/roboflow/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Auto Train YOLOv8 Model with Autodistill
#
# Autodistill uses big, slower foundation models to train small, faster supervised models. Using `autodistill`, you can go from unlabeled images to inference on a custom model running at the edge with no human intervention in between.
#
# ![Autodistill Steps](https://media.roboflow.com/open-source/autodistill/steps.jpg)
#
# As foundation models get better and better they will increasingly be able to augment or replace humans in the labeling process. We need tools for steering, utilizing, and comparing these models. Additionally, these foundation models are big, expensive, and often gated behind private APIs. For many production use-cases, we need models that can run cheaply and in realtime at the edge.
#
# ![Autodistill Connections](https://media.roboflow.com/open-source/autodistill/connections.jpg)
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Image dataset preperation
# - Autolabel dataset
# - Train target model
# - Evaluate target model
# - Run video inference
# - Upload dataset and model to Roboflow (comming soon)
#
# ## 🔥 Let's begin!

# %% [markdown]
# ## ⚡ Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !rm -rf yolov8l.pt

# %%
# !nvidia-smi
# Out:
# Mon Oct  9 07:43:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 🧪 Install autodistill
#
# **NOTE:** Autodistill is an ecosystem for using big, slower foundation models to train small, faster supervised models. Each Base, as well as the Target model, has its own separate repository and pip package.

# %%
# !pip install -q \
autodistill \
autodistill-grounded-sam \
autodistill-yolov8 \
supervision==0.9.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.4/82.4 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 31.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 31.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 26.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 69.2 MB/s eta 0:00:00
#   Building wheel for rf-groundingdino (setup.py) ... done

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## 🖼️ Image dataset preperation
#
# **NOTE:** To use Autodistill all you need to have is a set of images that you want to automatically annotate, and use for target model training.

# %%
# !mkdir {HOME}/images

# %% [markdown]
# **NOTE:** If you want to build YOLOv8 on your data make sure to upload it into `images` directory that we just created. ☝️

# %% [markdown]
# ### Download raw videos (optional)
#
# **NOTE:** In this tutorial, we will start with a directory containing video files and I will show you how to turn it into a ready-to-use collection of images. If you are working with your images, you can skip this part.

# %%
# !mkdir {HOME}/videos
# %cd {HOME}/videos
# Upload he2.mp4 video in videos folder.
# Out:
# /content/videos

# %%
# !mkdir {HOME}/videos
# %cd {HOME}/videos

# # download zip file containing videos
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt" -O milk.zip && rm -rf /tmp/cookies.txt

# # unzip videos
# !unzip milk.zip
# Out:
# /content/videos
# --2023-10-07 08:10:50--  https://docs.google.com/uc?export=download&confirm=t&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt
# Resolving docs.google.com (docs.google.com)... 142.251.2.138, 142.251.2.101, 142.251.2.100, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gvmsp04bll8sg94v8c9u5778aifh2l09/1696666200000/04309230031174164349/*/1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt?e=download&uuid=c63da460-b370-4a6f-80a2-ef60530891d9 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-07 08:10:50--  https://doc-08-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gvmsp04bll8sg94v8c9u5778aifh2l09/1696666200000/04309230031174164349/*/1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt?e=download&uuid=c63da460-b370-4a6f-80a2-ef60530891d9
# Resolving doc-08-ag-docs.googleusercontent.com (doc-08-ag-docs.googleusercontent.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to doc-08-ag-docs.googleusercontent.com (doc-08-ag-docs.googleusercontent.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1192719976 (1.1G) [application/zip]
# Saving to: ‘milk.zip’
#
# milk.zip            100%[===================>]   1.11G  92.0MB/s    in 12s
#
# 2023-10-07 08:11:03 (91.4 MB/s) - ‘milk.zip’ saved [1192719976/1192719976]
#
# Archive:  milk.zip
#   inflating: milk-video-1.mov
#   inflating: milk-video-2.mov
#   inflating: milk-video-3.mov
#   inflating: milk-video-4.mov
#   inflating: milk-video-5.mov
#   inflating: milk-video-6.mov
#   inflating: milk-video-7.mov
#   inflating: milk-video-8.mov

# %% [markdown]
# ### Convert videos into images (optional)
#
# **NOTE:** Now, let's convert videos into images. By default, the code below saves every `10th` frame from each video. You can change this by manipulating the value of the `FRAME_STRIDE` parameter.

# %%
VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 3

# %% [markdown]
# **NOTE:** Notice that we put two of our videos aside so that we can use them at the end of the notebook to evaluate our model.

# %%
import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

print(video_paths)

for video_path in tqdm(video_paths):
    video_name = video_path.stem
    image_name_pattern = video_name + "-{:05d}.png"
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            sink.save_image(image=image)
# Out:
# [PosixPath('/content/videos/he2.mp4')]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Display image sample
#
# **NOTE:** Before we start building a model with autodistill, let's make sure we have everything we need.

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 75

# %% [markdown]
# **NOTE:** We can also plot sample of our image dataset.

# %%
IMAGE_DIR_PATH = f"{HOME}/images"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 16)

# %%
import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🏷️ Autolabel dataset

# %% [markdown]
# ### Define ontology
#
# **Ontology** - an Ontology defines how your Base Model is prompted, what your Dataset will describe, and what your Target Model will predict. A simple Ontology is the CaptionOntology which prompts a Base Model with text captions and maps them to class names. Other Ontologies may, for instance, use a CLIP vector or example images instead of a text caption.

# %%
from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    "bike rider": "Bike_Rider",
    "helmet": "Helmet",
    "no helmet": "No_Helmet"
})

# %% [markdown]
# ### Initiate base model and autolabel
#
# **Base Model** - A Base Model is a large foundation model that knows a lot about a lot. Base models are often multimodal and can perform many tasks. They're large, slow, and expensive. Examples of Base Models are GroundedSAM and GPT-4's upcoming multimodal variant. We use a Base Model (along with unlabeled input data and an Ontology) to create a Dataset.

# %%
DATASET_DIR_PATH = f"{HOME}/dataset"

# %% [markdown]
# **NOTE:** Base Models are slow... Make yourself a coffee, autolabeing may take a while. ☕

# %%
from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# trying to load grounding dino directly
# downloading dino model weights
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Labeling /content/images/he2-00072.png:   0%|          | 0/75 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:905: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:905: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# Labeling /content/images/he2-00035.png: 100%|██████████| 75/75 [05:14<00:00,  4.20s/it]
# Labeled dataset created - ready for distillation.

# %% [markdown]
# ### Display dataset sample
#
# **Dataset** - a Dataset is a set of auto-labeled data that can be used to train a Target Model. It is the output generated by a Base Model.

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/dataset/train/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/dataset/train/images"
DATA_YAML_PATH = f"{HOME}/dataset/data.yaml"

# %%
import supervision as sv

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=IMAGES_DIRECTORY_PATH,
    annotations_directory_path=ANNOTATIONS_DIRECTORY_PATH,
    data_yaml_path=DATA_YAML_PATH)

len(dataset)
# Out:
# 60

# %%
import supervision as sv

image_names = list(dataset.images.keys())[:SAMPLE_SIZE]

mask_annotator = sv.MaskAnnotator()
box_annotator = sv.BoxAnnotator()

images = []
for image_name in image_names:
    image = dataset.images[image_name]
    annotations = dataset.annotations[image_name]
    labels = [
        dataset.classes[class_id]
        for class_id
        in annotations.class_id]
    annotates_image = mask_annotator.annotate(
        scene=image.copy(),
        detections=annotations)
    annotates_image = box_annotator.annotate(
        scene=annotates_image,
        detections=annotations,
        labels=labels)
    images.append(annotates_image)

sv.plot_images_grid(
    images=images,
    titles=image_names,
    grid_size=SAMPLE_GRID_SIZE,
    size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🔥 Train target model - YOLOv8
#
# **Target Model** - a Target Model is a supervised model that consumes a Dataset and outputs a distilled model that is ready for deployment. Target Models are usually small, fast, and fine-tuned to perform a specific task very well (but they don't generalize well beyond the information described in their Dataset). Examples of Target Models are YOLOv8 and DETR.

# %%
# %cd {HOME}

from autodistill_yolov8 import YOLOv8

target_model = YOLOv8("yolov8l.pt")
target_model.train(DATA_YAML_PATH, epochs=10) #100
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt to yolov8l.pt...
# 100%|██████████| 83.7M/83.7M [00:01<00:00, 71.1MB/s]
# New https://pypi.org/project/ultralytics/8.0.195 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8l.pt, data=/content/dataset/data.yaml, epochs=10, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 20.8MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.Conv                  [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.C2f                   [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.C2f                   [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.C2f                   [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.C2f                   [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.C2f                   [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.C2f                   [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  22        [15, 18, 21]  1   5585113  ultralytics.nn.modules.Detect                [3, [256, 512, 512]]
# Model summary: 365 layers, 43632153 parameters, 43632137 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 108MB/s]
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias
# train: Scanning /content/dataset/train/labels... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60/60 [00:00<00:00, 851.62it/s]
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/valid/labels... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<00:00, 301.55it/s]
# val: New cache created: /content/dataset/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      13.3G      3.171      5.301      2.177        176        640: 100%|██████████| 4/4 [00:10<00:00,  2.58s/it]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:08<00:00,  8.33s/it]
#                    all         15        184   0.000519     0.0625   0.000762   0.000209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      13.9G      3.217      5.087      2.186        241        640: 100%|██████████| 4/4 [00:02<00:00,  1.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
#                    all         15        184   0.000413     0.0521   0.000362   9.37e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10        14G      3.049      4.768      2.102        332        640: 100%|██████████| 4/4 [00:07<00:00,  1.89s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
#                    all         15        184   0.000555     0.0729   0.000391   8.42e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10        14G      2.999      4.814       2.13        235        640: 100%|██████████| 4/4 [00:07<00:00,  1.88s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
#                    all         15        184    0.00181     0.0518   0.000986   0.000148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      14.2G      2.714      4.604      1.852        272        640: 100%|██████████| 4/4 [00:06<00:00,  1.65s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
#                    all         15        184   0.000323     0.0417     0.0003   8.59e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      14.1G      2.361      4.433       1.68        222        640: 100%|██████████| 4/4 [00:05<00:00,  1.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.78it/s]
#                    all         15        184   0.000574     0.0625   0.000612   0.000289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      14.1G      2.228      4.054      1.633        244        640: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
#                    all         15        184    0.00128      0.104    0.00109   0.000466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      14.1G      2.258      3.783       1.59        236        640: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
#                    all         15        184      0.391     0.0104     0.0123    0.00313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      14.2G       2.06      3.375      1.487        226        640: 100%|██████████| 4/4 [00:02<00:00,  1.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.52it/s]
#                    all         15        184      0.388     0.0414     0.0252    0.00841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      14.2G      1.845      3.027      1.405        267        640: 100%|██████████| 4/4 [00:02<00:00,  1.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#                    all         15        184      0.398     0.0726     0.0305     0.0108
#
# 10 epochs completed in 0.049 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 87.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 87.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608921 parameters, 0 gradients, 164.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
#                    all         15        184      0.397     0.0726     0.0305     0.0109
#             Bike_Rider         15         32      0.158      0.188     0.0648     0.0177
#                 Helmet         15        119          1          0     0.0185     0.0109
#              No_Helmet         15         33     0.0332     0.0303    0.00815    0.00413
# Speed: 0.1ms preprocess, 12.2ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/train

# %% [markdown]
# ## ⚖️ Evaluate target model
#
# **NOTE:** As with the regular YOLOv8 training, we can now take a look at artifacts stored in `runs` directory.

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## 🎬 Run Inference on a video

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# TEST_VIDEO_PATHS = f"/content/videos/milk-video-1.mov"
INPUT_VIDEO_PATH = f"/content/videos/he2.mp4"
OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# # TEST_VIDEO_PATHS = f"/content/videos/milk-video-1.mov"
# INPUT_VIDEO_PATH = f"/content/videos/milk-video-1.mov"
# OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
# TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# TEST_VIDEO_PATHS = f"/content/videos/milk-video-1.mov"
# INPUT_VIDEO_PATH = TEST_VIDEO_PATHS[0]
# OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
# TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# !yolo predict model={TRAINED_MODEL_PATH} source={INPUT_VIDEO_PATH}
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608921 parameters, 0 gradients, 164.8 GFLOPs
#
# video 1/1 (1/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 104.5ms
# video 1/1 (2/224) /content/videos/he2.mp4: 384x640 (no detections), 40.8ms
# video 1/1 (3/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 40.7ms
# video 1/1 (4/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 40.7ms
# video 1/1 (5/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 3 No_Helmets, 29.0ms
# video 1/1 (6/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 29.0ms
# video 1/1 (7/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 28.3ms
# video 1/1 (8/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 26.6ms
# video 1/1 (9/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 24.5ms
# video 1/1 (10/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 2 No_Helmets, 23.9ms
# video 1/1 (11/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 23.6ms
# video 1/1 (12/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 22.8ms
# video 1/1 (13/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 22.8ms
# video 1/1 (14/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.2ms
# video 1/1 (15/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.2ms
# video 1/1 (16/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 20.4ms
# video 1/1 (17/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 20.4ms
# video 1/1 (18/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 20.4ms
# video 1/1 (19/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 20.3ms
# video 1/1 (20/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 2 No_Helmets, 20.2ms
# video 1/1 (21/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 20.2ms
# video 1/1 (22/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 20.0ms
# video 1/1 (23/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 27.0ms
# video 1/1 (24/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 20.2ms
# video 1/1 (25/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 20.0ms
# video 1/1 (26/224) /content/videos/he2.mp4: 384x640 (no detections), 25.3ms
# video 1/1 (27/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 20.0ms
# video 1/1 (28/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 20.0ms
# video 1/1 (29/224) /content/videos/he2.mp4: 384x640 (no detections), 25.2ms
# video 1/1 (30/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 26.1ms
# video 1/1 (31/224) /content/videos/he2.mp4: 384x640 (no detections), 22.8ms
# video 1/1 (32/224) /content/videos/he2.mp4: 384x640 (no detections), 22.9ms
# video 1/1 (33/224) /content/videos/he2.mp4: 384x640 (no detections), 26.4ms
# video 1/1 (34/224) /content/videos/he2.mp4: 384x640 (no detections), 21.3ms
# video 1/1 (35/224) /content/videos/he2.mp4: 384x640 (no detections), 25.2ms
# video 1/1 (36/224) /content/videos/he2.mp4: 384x640 (no detections), 27.9ms
# video 1/1 (37/224) /content/videos/he2.mp4: 384x640 (no detections), 22.6ms
# video 1/1 (38/224) /content/videos/he2.mp4: 384x640 (no detections), 19.9ms
# video 1/1 (39/224) /content/videos/he2.mp4: 384x640 (no detections), 24.2ms
# video 1/1 (40/224) /content/videos/he2.mp4: 384x640 (no detections), 26.7ms
# video 1/1 (41/224) /content/videos/he2.mp4: 384x640 (no detections), 20.1ms
# video 1/1 (42/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 20.0ms
# video 1/1 (43/224) /content/videos/he2.mp4: 384x640 (no detections), 24.8ms
# video 1/1 (44/224) /content/videos/he2.mp4: 384x640 (no detections), 20.2ms
# video 1/1 (45/224) /content/videos/he2.mp4: 384x640 (no detections), 20.7ms
# video 1/1 (46/224) /content/videos/he2.mp4: 384x640 (no detections), 20.2ms
# video 1/1 (47/224) /content/videos/he2.mp4: 384x640 (no detections), 24.1ms
# video 1/1 (48/224) /content/videos/he2.mp4: 384x640 (no detections), 23.7ms
# video 1/1 (49/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 31.0ms
# video 1/1 (50/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 24.6ms
# video 1/1 (51/224) /content/videos/he2.mp4: 384x640 (no detections), 23.8ms
# video 1/1 (52/224) /content/videos/he2.mp4: 384x640 (no detections), 23.6ms
# video 1/1 (53/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 29.5ms
# video 1/1 (54/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 24.6ms
# video 1/1 (55/224) /content/videos/he2.mp4: 384x640 (no detections), 23.8ms
# video 1/1 (56/224) /content/videos/he2.mp4: 384x640 (no detections), 23.9ms
# video 1/1 (57/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 23.8ms
# video 1/1 (58/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 23.8ms
# video 1/1 (59/224) /content/videos/he2.mp4: 384x640 (no detections), 23.6ms
# video 1/1 (60/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.8ms
# video 1/1 (61/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 27.7ms
# video 1/1 (62/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 21.9ms
# video 1/1 (63/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 25.1ms
# video 1/1 (64/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.0ms
# video 1/1 (65/224) /content/videos/he2.mp4: 384x640 (no detections), 22.3ms
# video 1/1 (66/224) /content/videos/he2.mp4: 384x640 (no detections), 22.0ms
# video 1/1 (67/224) /content/videos/he2.mp4: 384x640 4 Bike_Riders, 27.1ms
# video 1/1 (68/224) /content/videos/he2.mp4: 384x640 (no detections), 21.9ms
# video 1/1 (69/224) /content/videos/he2.mp4: 384x640 (no detections), 23.6ms
# video 1/1 (70/224) /content/videos/he2.mp4: 384x640 2 No_Helmets, 30.2ms
# video 1/1 (71/224) /content/videos/he2.mp4: 384x640 (no detections), 23.5ms
# video 1/1 (72/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.0ms
# video 1/1 (73/224) /content/videos/he2.mp4: 384x640 (no detections), 22.0ms
# video 1/1 (74/224) /content/videos/he2.mp4: 384x640 (no detections), 27.7ms
# video 1/1 (75/224) /content/videos/he2.mp4: 384x640 (no detections), 25.7ms
# video 1/1 (76/224) /content/videos/he2.mp4: 384x640 (no detections), 22.3ms
# video 1/1 (77/224) /content/videos/he2.mp4: 384x640 (no detections), 22.0ms
# video 1/1 (78/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 22.0ms
# video 1/1 (79/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.1ms
# video 1/1 (80/224) /content/videos/he2.mp4: 384x640 4 Bike_Riders, 25.4ms
# video 1/1 (81/224) /content/videos/he2.mp4: 384x640 4 Bike_Riders, 22.0ms
# video 1/1 (82/224) /content/videos/he2.mp4: 384x640 4 Bike_Riders, 28.5ms
# video 1/1 (83/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.0ms
# video 1/1 (84/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.0ms
# video 1/1 (85/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.0ms
# video 1/1 (86/224) /content/videos/he2.mp4: 384x640 (no detections), 25.1ms
# video 1/1 (87/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 25.7ms
# video 1/1 (88/224) /content/videos/he2.mp4: 384x640 6 Bike_Riders, 24.4ms
# video 1/1 (89/224) /content/videos/he2.mp4: 384x640 1 No_Helmet, 25.7ms
# video 1/1 (90/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 27.7ms
# video 1/1 (91/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 24.7ms
# video 1/1 (92/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 24.7ms
# video 1/1 (93/224) /content/videos/he2.mp4: 384x640 4 Bike_Riders, 24.7ms
# video 1/1 (94/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 24.7ms
# video 1/1 (95/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 25.9ms
# video 1/1 (96/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 24.7ms
# video 1/1 (97/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 24.6ms
# video 1/1 (98/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 24.9ms
# video 1/1 (99/224) /content/videos/he2.mp4: 384x640 (no detections), 25.1ms
# video 1/1 (100/224) /content/videos/he2.mp4: 384x640 (no detections), 24.5ms
# video 1/1 (101/224) /content/videos/he2.mp4: 384x640 (no detections), 24.1ms
# video 1/1 (102/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 22.0ms
# video 1/1 (103/224) /content/videos/he2.mp4: 384x640 4 Bike_Riders, 20.8ms
# video 1/1 (104/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 20.7ms
# video 1/1 (105/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 20.8ms
# video 1/1 (106/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 1 No_Helmet, 20.2ms
# video 1/1 (107/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.3ms
# video 1/1 (108/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.0ms
# video 1/1 (109/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 19.1ms
# video 1/1 (110/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 19.6ms
# video 1/1 (111/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.5ms
# video 1/1 (112/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.8ms
# video 1/1 (113/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 20.3ms
# video 1/1 (114/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (115/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.4ms
# video 1/1 (116/224) /content/videos/he2.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (117/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (118/224) /content/videos/he2.mp4: 384x640 2 No_Helmets, 19.7ms
# video 1/1 (119/224) /content/videos/he2.mp4: 384x640 (no detections), 18.8ms
# video 1/1 (120/224) /content/videos/he2.mp4: 384x640 (no detections), 19.1ms
# video 1/1 (121/224) /content/videos/he2.mp4: 384x640 (no detections), 19.8ms
# video 1/1 (122/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (123/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (124/224) /content/videos/he2.mp4: 384x640 (no detections), 19.4ms
# video 1/1 (125/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (126/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 19.5ms
# video 1/1 (127/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (128/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 19.4ms
# video 1/1 (129/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.7ms
# video 1/1 (130/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.2ms
# video 1/1 (131/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.5ms
# video 1/1 (132/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.0ms
# video 1/1 (133/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.5ms
# video 1/1 (134/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.7ms
# video 1/1 (135/224) /content/videos/he2.mp4: 384x640 1 Helmet, 19.6ms
# video 1/1 (136/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.5ms
# video 1/1 (137/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.8ms
# video 1/1 (138/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.5ms
# video 1/1 (139/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.3ms
# video 1/1 (140/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 19.6ms
# video 1/1 (141/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 1 No_Helmet, 18.8ms
# video 1/1 (142/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.8ms
# video 1/1 (143/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 2 No_Helmets, 19.4ms
# video 1/1 (144/224) /content/videos/he2.mp4: 384x640 (no detections), 18.6ms
# video 1/1 (145/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (146/224) /content/videos/he2.mp4: 384x640 (no detections), 19.9ms
# video 1/1 (147/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (148/224) /content/videos/he2.mp4: 384x640 (no detections), 19.4ms
# video 1/1 (149/224) /content/videos/he2.mp4: 384x640 (no detections), 19.1ms
# video 1/1 (150/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (151/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (152/224) /content/videos/he2.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (153/224) /content/videos/he2.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (154/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (155/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (156/224) /content/videos/he2.mp4: 384x640 (no detections), 19.4ms
# video 1/1 (157/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (158/224) /content/videos/he2.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (159/224) /content/videos/he2.mp4: 384x640 (no detections), 18.7ms
# video 1/1 (160/224) /content/videos/he2.mp4: 384x640 (no detections), 19.0ms
# video 1/1 (161/224) /content/videos/he2.mp4: 384x640 (no detections), 19.3ms
# video 1/1 (162/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (163/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 19.5ms
# video 1/1 (164/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (165/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 19.6ms
# video 1/1 (166/224) /content/videos/he2.mp4: 384x640 1 No_Helmet, 19.6ms
# video 1/1 (167/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (168/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (169/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 1 No_Helmet, 19.6ms
# video 1/1 (170/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.1ms
# video 1/1 (171/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 19.5ms
# video 1/1 (172/224) /content/videos/he2.mp4: 384x640 1 No_Helmet, 19.0ms
# video 1/1 (173/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 19.1ms
# video 1/1 (174/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 19.6ms
# video 1/1 (175/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.1ms
# video 1/1 (176/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (177/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (178/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.1ms
# video 1/1 (179/224) /content/videos/he2.mp4: 384x640 (no detections), 19.1ms
# video 1/1 (180/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 19.6ms
# video 1/1 (181/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 19.4ms
# video 1/1 (182/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 18.6ms
# video 1/1 (183/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (184/224) /content/videos/he2.mp4: 384x640 (no detections), 19.7ms
# video 1/1 (185/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (186/224) /content/videos/he2.mp4: 384x640 (no detections), 18.6ms
# video 1/1 (187/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (188/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (189/224) /content/videos/he2.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (190/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.6ms
# video 1/1 (191/224) /content/videos/he2.mp4: 384x640 (no detections), 18.8ms
# video 1/1 (192/224) /content/videos/he2.mp4: 384x640 (no detections), 19.7ms
# video 1/1 (193/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (194/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (195/224) /content/videos/he2.mp4: 384x640 (no detections), 19.4ms
# video 1/1 (196/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (197/224) /content/videos/he2.mp4: 384x640 (no detections), 19.8ms
# video 1/1 (198/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.6ms
# video 1/1 (199/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (200/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.9ms
# video 1/1 (201/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.6ms
# video 1/1 (202/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.0ms
# video 1/1 (203/224) /content/videos/he2.mp4: 384x640 3 Bike_Riders, 19.5ms
# video 1/1 (204/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 18.7ms
# video 1/1 (205/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.0ms
# video 1/1 (206/224) /content/videos/he2.mp4: 384x640 2 Bike_Riders, 19.7ms
# video 1/1 (207/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 19.4ms
# video 1/1 (208/224) /content/videos/he2.mp4: 384x640 (no detections), 22.7ms
# video 1/1 (209/224) /content/videos/he2.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (210/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (211/224) /content/videos/he2.mp4: 384x640 2 No_Helmets, 19.5ms
# video 1/1 (212/224) /content/videos/he2.mp4: 384x640 (no detections), 18.7ms
# video 1/1 (213/224) /content/videos/he2.mp4: 384x640 5 No_Helmets, 19.1ms
# video 1/1 (214/224) /content/videos/he2.mp4: 384x640 (no detections), 19.6ms
# video 1/1 (215/224) /content/videos/he2.mp4: 384x640 1 Bike_Rider, 1 No_Helmet, 19.3ms
# video 1/1 (216/224) /content/videos/he2.mp4: 384x640 2 No_Helmets, 19.1ms
# video 1/1 (217/224) /content/videos/he2.mp4: 384x640 (no detections), 19.7ms
# video 1/1 (218/224) /content/videos/he2.mp4: 384x640 3 No_Helmets, 19.8ms
# video 1/1 (219/224) /content/videos/he2.mp4: 384x640 (no detections), 19.8ms
# video 1/1 (220/224) /content/videos/he2.mp4: 384x640 (no detections), 19.8ms
# video 1/1 (221/224) /content/videos/he2.mp4: 384x640 (no detections), 19.9ms
# video 1/1 (222/224) /content/videos/he2.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (223/224) /content/videos/he2.mp4: 384x640 (no detections), 19.0ms
# video 1/1 (224/224) /content/videos/he2.mp4: 384x640 (no detections), 19.2ms
# Speed: 0.7ms preprocess, 22.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# ## Export Model to Custom Python Script and Project

# %%
# yolo export model=yolov8n.pt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mkdir -p /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/runs /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/dataset /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/images /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/videos /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/yolov8l.pt /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/yolov8n.pt /content/gdrive/MyDrive/YOLOv8_bottle/
